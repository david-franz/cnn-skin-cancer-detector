# %% [markdown]
# <a href="https://colab.research.google.com/github/david-franz/CNN-Skin-Cancer-Detector/blob/main/paper_params_cnn_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN Baseline (Paper Params)

# %% [markdown]
# ## 1. Setup

# %%
import os, math, time, json, random
from pathlib import Path

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.optim import Adam
from torchvision import datasets, transforms

import numpy as np

# Reproducibility
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 2. Data

# %%
import math, time
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torch.nn as nn
from torchvision.transforms import ToTensor
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

import os
import pandas as pd
from PIL import Image
from IPython.display import Image as IPythonImage

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nodoubttome/skin-cancer9-classesisic")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'skin-cancer9-classesisic' dataset.
# Path to dataset files: /kaggle/input/skin-cancer9-classesisic

# %%
base_filepath = path + '/Skin cancer ISIC The International Skin Imaging Collaboration'

# Example of a simple preprocessing function
def preprocess_image(image_path, target_size=(28, 28)):
    img = Image.open(image_path).resize(target_size)
    return ToTensor()(img)

data = []
classes = os.listdir(base_filepath + '/Train')
for tt in os.listdir(base_filepath):
    for type in classes:
        for file in os.listdir(base_filepath + '/' + tt + '/' + type):
            constructed_filepath = base_filepath + '/' + tt + '/' + type + '/' + file
            data.append({'label': type, 'image': preprocess_image(constructed_filepath)})

# %%
len(data)
# Out:
# 2357

# %%
from torch.utils.data import random_split, TensorDataset

def get_data_split(d, train_percentage=0.72):
    data = d.copy()
    random.shuffle(data)

    if train_percentage < 0 or train_percentage > 1:
        raise ValueError("train_percentage must be between 0 and 1")

    data_length = len(data)

    train_size = int(train_percentage * data_length)
    test_size = int((1 - train_percentage) * 0.72 * data_length)
    val_size = data_length - train_size - test_size

    print(train_size)

    train_dataset, val_dataset, test_dataset = random_split(data, [train_size, val_size, test_size])

    return train_dataset, test_dataset, val_dataset

# %%
data_train, data_test, data_val = get_data_split(data)
# Out:
# 1697

# %%
print(len(data_train))
print(len(data_test))
print(len(data_val))
# Out:
# 1697
# 475
# 185

# %%
def time_function(func):
    start_time = time.time()
    func()
    end_time = time.time()
    return end_time - start_time

# %%
# Separate images and labels
train_images = torch.stack([item['image'] for item in data_train])
test_images = torch.stack([item['image'] for item in data_test])
val_images = torch.stack([item['image'] for item in data_val])

# Get unique labels and create a mapping
unique_labels = sorted(list(set([item['label'] for item in data])))
label_to_int = {label: i for i, label in enumerate(unique_labels)}

# Convert string labels to numerical labels
train_labels = torch.tensor([label_to_int[item['label']] for item in data_train], dtype=torch.long)
test_labels = torch.tensor([label_to_int[item['label']] for item in data_test], dtype=torch.long)
val_labels = torch.tensor([label_to_int[item['label']] for item in data_val], dtype=torch.long)

# Create TensorDatasets
train_dataset = TensorDataset(train_images, train_labels)  # Convert data to tensors
test_dataset = TensorDataset(test_images, test_labels)  # Convert data to tensors
val_dataset = TensorDataset(val_images, val_labels)  # Convert data to tensors

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# ## 3. Model (3× Conv → Pool+BN; Flatten → Dense×3 w/ Dropout)

# %%
class PaperStyleCNN(nn.Module):
    def __init__(self, num_classes: int):
        super().__init__()
        # Three conv blocks: Conv(3x3) → MaxPool(2x2) → BatchNorm → ReLU
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1, bias=False)
        self.bn1   = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1, bias=False)
        self.bn2   = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1, bias=False)
        self.bn3   = nn.BatchNorm2d(128)

        # After 3 × MaxPool(2), spatial dims reduce: img_size / 2 / 2 / 2
        with torch.no_grad():
            dummy = torch.zeros(1, 3, 28, 28)
            h = self._forward_features(dummy)
            flat_dim = h.numel()

        self.dropout = nn.Dropout(p=0.5)
        self.fc1 = nn.Linear(flat_dim, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 32)
        self.out = nn.Linear(32, num_classes)

    def _forward_features(self, x):
        x = F.relu(self.bn1(F.max_pool2d(self.conv1(x), 2)))
        x = F.relu(self.bn2(F.max_pool2d(self.conv2(x), 2)))
        x = F.relu(self.bn3(F.max_pool2d(self.conv3(x), 2)))
        return torch.flatten(x, 1)

    def forward(self, x):
        x = self._forward_features(x)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        return self.out(x)

model = PaperStyleCNN(num_classes=len(classes)).to(device)
sum(p.numel() for p in model.parameters()), model
# Out:
# (251689,
#  PaperStyleCNN(
#    (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#    (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#    (dropout): Dropout(p=0.5, inplace=False)
#    (fc1): Linear(in_features=1152, out_features=128, bias=True)
#    (fc2): Linear(in_features=128, out_features=64, bias=True)
#    (fc3): Linear(in_features=64, out_features=32, bias=True)
#    (out): Linear(in_features=32, out_features=9, bias=True)
#  ))

# %% [markdown]
# ## 4. Training Setup

# %%
epochs = 100
lr = 1e-4
criterion = nn.CrossEntropyLoss()  # for mutliclass classification
optimizer = Adam(model.parameters(), lr=lr)

def accuracy_from_logits(logits, targets):
    preds = torch.argmax(logits, dim=1)
    return (preds == targets).float().mean().item()

best_val_acc = 0.0
history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

# %% [markdown]
# ## 5. Train

# %%
def train_model(model, train_loader, val_loader, epochs, optimizer, criterion, device, best_val_acc):
  for epoch in range(1, epochs + 1):
      model.train()
      train_loss, train_acc, n_train = 0.0, 0.0, 0
      for images, targets in train_loader:
          images, targets = images.to(device), targets.to(device)
          optimizer.zero_grad()
          logits = model(images)
          loss = criterion(logits, targets)
          loss.backward()
          optimizer.step()

          bsz = targets.size(0)
          train_loss += loss.item() * bsz
          train_acc  += accuracy_from_logits(logits, targets) * bsz
          n_train    += bsz

      train_loss /= max(n_train, 1)
      train_acc  /= max(n_train, 1)

      model.eval()
      val_loss, val_acc, n_val = 0.0, 0.0, 0
      with torch.inference_mode():
          for images, targets in val_loader:
              images, targets = images.to(device), targets.to(device)
              logits = model(images)
              loss = criterion(logits, targets)

              bsz = targets.size(0)
              val_loss += loss.item() * bsz
              val_acc  += accuracy_from_logits(logits, targets) * bsz
              n_val    += bsz

      val_loss /= max(n_val, 1)
      val_acc  /= max(n_val, 1)

      history["train_loss"].append(train_loss)
      history["train_acc"].append(train_acc)
      history["val_loss"].append(val_loss)
      history["val_acc"].append(val_acc)

      if val_acc > best_val_acc:
          best_val_acc = val_acc
          torch.save(model.state_dict(), "paper_style_cnn_best.pt")

      print(f"Epoch [{epoch:02d}/{epochs}]  "
            f"Train Loss: {train_loss:.4f} | Acc: {train_acc:.4f}  "
            f"Val Loss: {val_loss:.4f} | Acc: {val_acc:.4f}  "
            f"(best val acc: {best_val_acc:.4f})")

# %%
timeit = time_function(lambda: train_model(model, train_loader, val_loader, epochs, optimizer, criterion, device, best_val_acc))
# Out:
# Epoch [01/250]  Train Loss: 2.2213 | Acc: 0.0577  Val Loss: 2.2156 | Acc: 0.0757  (best val acc: 0.0757)
# Epoch [02/250]  Train Loss: 2.2075 | Acc: 0.0801  Val Loss: 2.1946 | Acc: 0.0757  (best val acc: 0.0757)
# Epoch [03/250]  Train Loss: 2.1823 | Acc: 0.1126  Val Loss: 2.1518 | Acc: 0.1892  (best val acc: 0.1892)
# Epoch [04/250]  Train Loss: 2.1622 | Acc: 0.1326  Val Loss: 2.1095 | Acc: 0.1838  (best val acc: 0.1892)
# Epoch [05/250]  Train Loss: 2.1274 | Acc: 0.1691  Val Loss: 2.0540 | Acc: 0.1838  (best val acc: 0.1892)
# Epoch [06/250]  Train Loss: 2.0868 | Acc: 0.1862  Val Loss: 1.9978 | Acc: 0.1838  (best val acc: 0.1892)
# Epoch [07/250]  Train Loss: 2.0500 | Acc: 0.2045  Val Loss: 1.9482 | Acc: 0.1892  (best val acc: 0.1892)
# Epoch [08/250]  Train Loss: 2.0229 | Acc: 0.2033  Val Loss: 1.9088 | Acc: 0.1946  (best val acc: 0.1946)
# Epoch [09/250]  Train Loss: 2.0099 | Acc: 0.2157  Val Loss: 1.8849 | Acc: 0.2162  (best val acc: 0.2162)
# Epoch [10/250]  Train Loss: 1.9770 | Acc: 0.2463  Val Loss: 1.8610 | Acc: 0.3189  (best val acc: 0.3189)
# Epoch [11/250]  Train Loss: 1.9369 | Acc: 0.2569  Val Loss: 1.8290 | Acc: 0.3189  (best val acc: 0.3189)
# Epoch [12/250]  Train Loss: 1.9112 | Acc: 0.2770  Val Loss: 1.7825 | Acc: 0.3784  (best val acc: 0.3784)
# Epoch [13/250]  Train Loss: 1.8878 | Acc: 0.2929  Val Loss: 1.7564 | Acc: 0.3946  (best val acc: 0.3946)
# Epoch [14/250]  Train Loss: 1.8433 | Acc: 0.3235  Val Loss: 1.7189 | Acc: 0.3892  (best val acc: 0.3946)
# Epoch [15/250]  Train Loss: 1.8487 | Acc: 0.3341  Val Loss: 1.6969 | Acc: 0.4378  (best val acc: 0.4378)
# Epoch [16/250]  Train Loss: 1.8091 | Acc: 0.3559  Val Loss: 1.6695 | Acc: 0.4432  (best val acc: 0.4432)
# Epoch [17/250]  Train Loss: 1.7910 | Acc: 0.3819  Val Loss: 1.6392 | Acc: 0.4757  (best val acc: 0.4757)
# Epoch [18/250]  Train Loss: 1.7454 | Acc: 0.3889  Val Loss: 1.6061 | Acc: 0.4649  (best val acc: 0.4757)
# Epoch [19/250]  Train Loss: 1.7186 | Acc: 0.4090  Val Loss: 1.5726 | Acc: 0.4703  (best val acc: 0.4757)
# Epoch [20/250]  Train Loss: 1.7090 | Acc: 0.4060  Val Loss: 1.5548 | Acc: 0.4973  (best val acc: 0.4973)
# Epoch [21/250]  Train Loss: 1.7033 | Acc: 0.4349  Val Loss: 1.5509 | Acc: 0.4865  (best val acc: 0.4973)
# Epoch [22/250]  Train Loss: 1.6483 | Acc: 0.4414  Val Loss: 1.5089 | Acc: 0.4703  (best val acc: 0.4973)
# Epoch [23/250]  Train Loss: 1.6443 | Acc: 0.4537  Val Loss: 1.4847 | Acc: 0.5243  (best val acc: 0.5243)
# Epoch [24/250]  Train Loss: 1.5940 | Acc: 0.4667  Val Loss: 1.4632 | Acc: 0.5081  (best val acc: 0.5243)
# Epoch [25/250]  Train Loss: 1.6057 | Acc: 0.4549  Val Loss: 1.4713 | Acc: 0.5243  (best val acc: 0.5243)
# Epoch [26/250]  Train Loss: 1.5740 | Acc: 0.4779  Val Loss: 1.4543 | Acc: 0.5135  (best val acc: 0.5243)
# Epoch [27/250]  Train Loss: 1.5597 | Acc: 0.4791  Val Loss: 1.4547 | Acc: 0.5027  (best val acc: 0.5243)
# Epoch [28/250]  Train Loss: 1.5220 | Acc: 0.4956  Val Loss: 1.4044 | Acc: 0.5568  (best val acc: 0.5568)
# Epoch [29/250]  Train Loss: 1.5384 | Acc: 0.4956  Val Loss: 1.4094 | Acc: 0.5351  (best val acc: 0.5568)
# Epoch [30/250]  Train Loss: 1.5022 | Acc: 0.5015  Val Loss: 1.4323 | Acc: 0.5243  (best val acc: 0.5568)
# Epoch [31/250]  Train Loss: 1.4909 | Acc: 0.4979  Val Loss: 1.4175 | Acc: 0.5405  (best val acc: 0.5568)
# Epoch [32/250]  Train Loss: 1.4481 | Acc: 0.5215  Val Loss: 1.4021 | Acc: 0.5405  (best val acc: 0.5568)
# Epoch [33/250]  Train Loss: 1.4332 | Acc: 0.5292  Val Loss: 1.3810 | Acc: 0.5459  (best val acc: 0.5568)
# Epoch [34/250]  Train Loss: 1.4137 | Acc: 0.5427  Val Loss: 1.3864 | Acc: 0.5622  (best val acc: 0.5622)
# Epoch [35/250]  Train Loss: 1.4112 | Acc: 0.5303  Val Loss: 1.3912 | Acc: 0.5730  (best val acc: 0.5730)
# Epoch [36/250]  Train Loss: 1.3898 | Acc: 0.5551  Val Loss: 1.3276 | Acc: 0.5784  (best val acc: 0.5784)
# Epoch [37/250]  Train Loss: 1.3424 | Acc: 0.5616  Val Loss: 1.3876 | Acc: 0.5351  (best val acc: 0.5784)
# Epoch [38/250]  Train Loss: 1.3221 | Acc: 0.5633  Val Loss: 1.3598 | Acc: 0.5459  (best val acc: 0.5784)
# Epoch [39/250]  Train Loss: 1.3199 | Acc: 0.5740  Val Loss: 1.3524 | Acc: 0.5459  (best val acc: 0.5784)
# Epoch [40/250]  Train Loss: 1.3012 | Acc: 0.5663  Val Loss: 1.3486 | Acc: 0.5568  (best val acc: 0.5784)
# Epoch [41/250]  Train Loss: 1.2736 | Acc: 0.5922  Val Loss: 1.3183 | Acc: 0.5784  (best val acc: 0.5784)
# Epoch [42/250]  Train Loss: 1.2833 | Acc: 0.5763  Val Loss: 1.4084 | Acc: 0.5351  (best val acc: 0.5784)
# Epoch [43/250]  Train Loss: 1.2283 | Acc: 0.6040  Val Loss: 1.3523 | Acc: 0.5730  (best val acc: 0.5784)
# Epoch [44/250]  Train Loss: 1.1996 | Acc: 0.6111  Val Loss: 1.3408 | Acc: 0.5514  (best val acc: 0.5784)
# Epoch [45/250]  Train Loss: 1.2042 | Acc: 0.5999  Val Loss: 1.3591 | Acc: 0.5351  (best val acc: 0.5784)
# Epoch [46/250]  Train Loss: 1.1580 | Acc: 0.6193  Val Loss: 1.3222 | Acc: 0.5676  (best val acc: 0.5784)
# Epoch [47/250]  Train Loss: 1.1494 | Acc: 0.6317  Val Loss: 1.3180 | Acc: 0.5568  (best val acc: 0.5784)
# Epoch [48/250]  Train Loss: 1.1280 | Acc: 0.6205  Val Loss: 1.3358 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [49/250]  Train Loss: 1.1411 | Acc: 0.6246  Val Loss: 1.3594 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [50/250]  Train Loss: 1.0872 | Acc: 0.6435  Val Loss: 1.3442 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [51/250]  Train Loss: 1.0797 | Acc: 0.6352  Val Loss: 1.3149 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [52/250]  Train Loss: 1.0797 | Acc: 0.6488  Val Loss: 1.3489 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [53/250]  Train Loss: 1.0678 | Acc: 0.6464  Val Loss: 1.3506 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [54/250]  Train Loss: 1.0160 | Acc: 0.6671  Val Loss: 1.3560 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [55/250]  Train Loss: 1.0108 | Acc: 0.6647  Val Loss: 1.3495 | Acc: 0.5838  (best val acc: 0.5892)
# Epoch [56/250]  Train Loss: 0.9983 | Acc: 0.6582  Val Loss: 1.3428 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [57/250]  Train Loss: 1.0069 | Acc: 0.6582  Val Loss: 1.3801 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [58/250]  Train Loss: 0.9627 | Acc: 0.6753  Val Loss: 1.3600 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [59/250]  Train Loss: 0.9595 | Acc: 0.6747  Val Loss: 1.3727 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [60/250]  Train Loss: 0.9363 | Acc: 0.6841  Val Loss: 1.3375 | Acc: 0.5838  (best val acc: 0.5892)
# Epoch [61/250]  Train Loss: 0.9180 | Acc: 0.7018  Val Loss: 1.4108 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [62/250]  Train Loss: 0.8883 | Acc: 0.7130  Val Loss: 1.4263 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [63/250]  Train Loss: 0.9072 | Acc: 0.6971  Val Loss: 1.3836 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [64/250]  Train Loss: 0.8804 | Acc: 0.7036  Val Loss: 1.4297 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [65/250]  Train Loss: 0.8608 | Acc: 0.7077  Val Loss: 1.4009 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [66/250]  Train Loss: 0.8631 | Acc: 0.7089  Val Loss: 1.4693 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [67/250]  Train Loss: 0.8444 | Acc: 0.7230  Val Loss: 1.5065 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [68/250]  Train Loss: 0.8328 | Acc: 0.7189  Val Loss: 1.4135 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [69/250]  Train Loss: 0.8209 | Acc: 0.7189  Val Loss: 1.4248 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [70/250]  Train Loss: 0.7918 | Acc: 0.7266  Val Loss: 1.4732 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [71/250]  Train Loss: 0.8153 | Acc: 0.7225  Val Loss: 1.4498 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [72/250]  Train Loss: 0.7779 | Acc: 0.7348  Val Loss: 1.4365 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [73/250]  Train Loss: 0.7778 | Acc: 0.7301  Val Loss: 1.4964 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [74/250]  Train Loss: 0.7585 | Acc: 0.7378  Val Loss: 1.4844 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [75/250]  Train Loss: 0.7265 | Acc: 0.7419  Val Loss: 1.5404 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [76/250]  Train Loss: 0.7515 | Acc: 0.7395  Val Loss: 1.4856 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [77/250]  Train Loss: 0.7063 | Acc: 0.7496  Val Loss: 1.6190 | Acc: 0.5297  (best val acc: 0.5892)
# Epoch [78/250]  Train Loss: 0.7504 | Acc: 0.7372  Val Loss: 1.5009 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [79/250]  Train Loss: 0.7218 | Acc: 0.7466  Val Loss: 1.6411 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [80/250]  Train Loss: 0.7132 | Acc: 0.7513  Val Loss: 1.5604 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [81/250]  Train Loss: 0.6904 | Acc: 0.7555  Val Loss: 1.5531 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [82/250]  Train Loss: 0.7012 | Acc: 0.7572  Val Loss: 1.5099 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [83/250]  Train Loss: 0.6878 | Acc: 0.7572  Val Loss: 1.6208 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [84/250]  Train Loss: 0.6748 | Acc: 0.7613  Val Loss: 1.5326 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [85/250]  Train Loss: 0.6580 | Acc: 0.7655  Val Loss: 1.6157 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [86/250]  Train Loss: 0.6546 | Acc: 0.7702  Val Loss: 1.5412 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [87/250]  Train Loss: 0.6727 | Acc: 0.7631  Val Loss: 1.6924 | Acc: 0.5351  (best val acc: 0.5892)
# Epoch [88/250]  Train Loss: 0.6224 | Acc: 0.7885  Val Loss: 1.5473 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [89/250]  Train Loss: 0.6325 | Acc: 0.7767  Val Loss: 1.6689 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [90/250]  Train Loss: 0.6407 | Acc: 0.7720  Val Loss: 1.6739 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [91/250]  Train Loss: 0.6259 | Acc: 0.7861  Val Loss: 1.6076 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [92/250]  Train Loss: 0.5985 | Acc: 0.7784  Val Loss: 1.6728 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [93/250]  Train Loss: 0.6053 | Acc: 0.7831  Val Loss: 1.6737 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [94/250]  Train Loss: 0.5963 | Acc: 0.7890  Val Loss: 1.6931 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [95/250]  Train Loss: 0.5854 | Acc: 0.7967  Val Loss: 1.8251 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [96/250]  Train Loss: 0.5945 | Acc: 0.7873  Val Loss: 1.6423 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [97/250]  Train Loss: 0.5591 | Acc: 0.7985  Val Loss: 1.8096 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [98/250]  Train Loss: 0.5792 | Acc: 0.7967  Val Loss: 1.7560 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [99/250]  Train Loss: 0.5787 | Acc: 0.7896  Val Loss: 1.7410 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [100/250]  Train Loss: 0.5608 | Acc: 0.7985  Val Loss: 1.7075 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [101/250]  Train Loss: 0.5517 | Acc: 0.7991  Val Loss: 1.7879 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [102/250]  Train Loss: 0.5379 | Acc: 0.8108  Val Loss: 1.7391 | Acc: 0.5351  (best val acc: 0.5892)
# Epoch [103/250]  Train Loss: 0.5332 | Acc: 0.7996  Val Loss: 1.8096 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [104/250]  Train Loss: 0.5336 | Acc: 0.8120  Val Loss: 1.7841 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [105/250]  Train Loss: 0.5177 | Acc: 0.8108  Val Loss: 1.8205 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [106/250]  Train Loss: 0.5453 | Acc: 0.8067  Val Loss: 1.6360 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [107/250]  Train Loss: 0.5482 | Acc: 0.8026  Val Loss: 1.7749 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [108/250]  Train Loss: 0.5150 | Acc: 0.8150  Val Loss: 1.8507 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [109/250]  Train Loss: 0.4832 | Acc: 0.8256  Val Loss: 1.8855 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [110/250]  Train Loss: 0.4826 | Acc: 0.8220  Val Loss: 1.8759 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [111/250]  Train Loss: 0.4878 | Acc: 0.8220  Val Loss: 1.9352 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [112/250]  Train Loss: 0.4858 | Acc: 0.8326  Val Loss: 1.9314 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [113/250]  Train Loss: 0.5008 | Acc: 0.8321  Val Loss: 1.8804 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [114/250]  Train Loss: 0.4916 | Acc: 0.8268  Val Loss: 2.0170 | Acc: 0.5189  (best val acc: 0.5892)
# Epoch [115/250]  Train Loss: 0.4973 | Acc: 0.8403  Val Loss: 1.8221 | Acc: 0.5243  (best val acc: 0.5892)
# Epoch [116/250]  Train Loss: 0.4665 | Acc: 0.8338  Val Loss: 1.9092 | Acc: 0.5189  (best val acc: 0.5892)
# Epoch [117/250]  Train Loss: 0.4808 | Acc: 0.8244  Val Loss: 1.9958 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [118/250]  Train Loss: 0.4634 | Acc: 0.8238  Val Loss: 1.9530 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [119/250]  Train Loss: 0.4471 | Acc: 0.8486  Val Loss: 1.9072 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [120/250]  Train Loss: 0.4476 | Acc: 0.8391  Val Loss: 1.9755 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [121/250]  Train Loss: 0.4624 | Acc: 0.8326  Val Loss: 2.0469 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [122/250]  Train Loss: 0.4118 | Acc: 0.8562  Val Loss: 1.9779 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [123/250]  Train Loss: 0.4311 | Acc: 0.8427  Val Loss: 1.9512 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [124/250]  Train Loss: 0.4204 | Acc: 0.8468  Val Loss: 2.0116 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [125/250]  Train Loss: 0.4262 | Acc: 0.8527  Val Loss: 1.8457 | Acc: 0.5189  (best val acc: 0.5892)
# Epoch [126/250]  Train Loss: 0.4186 | Acc: 0.8562  Val Loss: 1.9979 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [127/250]  Train Loss: 0.4204 | Acc: 0.8456  Val Loss: 2.0823 | Acc: 0.5243  (best val acc: 0.5892)
# Epoch [128/250]  Train Loss: 0.4299 | Acc: 0.8533  Val Loss: 2.1650 | Acc: 0.5297  (best val acc: 0.5892)
# Epoch [129/250]  Train Loss: 0.4052 | Acc: 0.8568  Val Loss: 2.2870 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [130/250]  Train Loss: 0.3881 | Acc: 0.8639  Val Loss: 2.0358 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [131/250]  Train Loss: 0.4055 | Acc: 0.8580  Val Loss: 2.0230 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [132/250]  Train Loss: 0.4140 | Acc: 0.8580  Val Loss: 1.9028 | Acc: 0.5351  (best val acc: 0.5892)
# Epoch [133/250]  Train Loss: 0.3994 | Acc: 0.8580  Val Loss: 2.0606 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [134/250]  Train Loss: 0.3808 | Acc: 0.8674  Val Loss: 1.9779 | Acc: 0.5351  (best val acc: 0.5892)
# Epoch [135/250]  Train Loss: 0.3842 | Acc: 0.8580  Val Loss: 1.9980 | Acc: 0.5351  (best val acc: 0.5892)
# Epoch [136/250]  Train Loss: 0.3659 | Acc: 0.8574  Val Loss: 2.1125 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [137/250]  Train Loss: 0.3781 | Acc: 0.8639  Val Loss: 2.0745 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [138/250]  Train Loss: 0.3677 | Acc: 0.8615  Val Loss: 2.1673 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [139/250]  Train Loss: 0.3642 | Acc: 0.8633  Val Loss: 2.2040 | Acc: 0.5297  (best val acc: 0.5892)
# Epoch [140/250]  Train Loss: 0.3622 | Acc: 0.8651  Val Loss: 2.0789 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [141/250]  Train Loss: 0.3717 | Acc: 0.8639  Val Loss: 2.0947 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [142/250]  Train Loss: 0.3641 | Acc: 0.8662  Val Loss: 2.1881 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [143/250]  Train Loss: 0.3604 | Acc: 0.8698  Val Loss: 2.0745 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [144/250]  Train Loss: 0.3576 | Acc: 0.8680  Val Loss: 2.1626 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [145/250]  Train Loss: 0.3564 | Acc: 0.8645  Val Loss: 2.3838 | Acc: 0.5081  (best val acc: 0.5892)
# Epoch [146/250]  Train Loss: 0.3504 | Acc: 0.8721  Val Loss: 2.0373 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [147/250]  Train Loss: 0.3386 | Acc: 0.8845  Val Loss: 2.3299 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [148/250]  Train Loss: 0.3536 | Acc: 0.8645  Val Loss: 2.3605 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [149/250]  Train Loss: 0.3666 | Acc: 0.8686  Val Loss: 2.0697 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [150/250]  Train Loss: 0.3485 | Acc: 0.8768  Val Loss: 2.1332 | Acc: 0.5838  (best val acc: 0.5892)
# Epoch [151/250]  Train Loss: 0.3422 | Acc: 0.8763  Val Loss: 2.2832 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [152/250]  Train Loss: 0.3412 | Acc: 0.8798  Val Loss: 2.2931 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [153/250]  Train Loss: 0.3161 | Acc: 0.8763  Val Loss: 2.3191 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [154/250]  Train Loss: 0.3440 | Acc: 0.8821  Val Loss: 2.1932 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [155/250]  Train Loss: 0.3375 | Acc: 0.8727  Val Loss: 2.2434 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [156/250]  Train Loss: 0.3105 | Acc: 0.8869  Val Loss: 2.2581 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [157/250]  Train Loss: 0.3092 | Acc: 0.8810  Val Loss: 2.3505 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [158/250]  Train Loss: 0.3193 | Acc: 0.8827  Val Loss: 2.2472 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [159/250]  Train Loss: 0.3015 | Acc: 0.8904  Val Loss: 2.3414 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [160/250]  Train Loss: 0.3047 | Acc: 0.8928  Val Loss: 2.2757 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [161/250]  Train Loss: 0.3151 | Acc: 0.8821  Val Loss: 2.2991 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [162/250]  Train Loss: 0.3186 | Acc: 0.8827  Val Loss: 2.1874 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [163/250]  Train Loss: 0.3296 | Acc: 0.8715  Val Loss: 2.2414 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [164/250]  Train Loss: 0.3115 | Acc: 0.8863  Val Loss: 2.1934 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [165/250]  Train Loss: 0.3037 | Acc: 0.8874  Val Loss: 2.3630 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [166/250]  Train Loss: 0.2896 | Acc: 0.8922  Val Loss: 2.2758 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [167/250]  Train Loss: 0.2837 | Acc: 0.8922  Val Loss: 2.3580 | Acc: 0.5297  (best val acc: 0.5892)
# Epoch [168/250]  Train Loss: 0.2971 | Acc: 0.8904  Val Loss: 2.3867 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [169/250]  Train Loss: 0.2980 | Acc: 0.8904  Val Loss: 2.4710 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [170/250]  Train Loss: 0.2812 | Acc: 0.8957  Val Loss: 2.3062 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [171/250]  Train Loss: 0.2914 | Acc: 0.8833  Val Loss: 2.4118 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [172/250]  Train Loss: 0.2887 | Acc: 0.8869  Val Loss: 2.3864 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [173/250]  Train Loss: 0.3036 | Acc: 0.8845  Val Loss: 2.4168 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [174/250]  Train Loss: 0.2766 | Acc: 0.8957  Val Loss: 2.4001 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [175/250]  Train Loss: 0.2980 | Acc: 0.8910  Val Loss: 2.4397 | Acc: 0.5189  (best val acc: 0.5892)
# Epoch [176/250]  Train Loss: 0.2855 | Acc: 0.8957  Val Loss: 2.4871 | Acc: 0.5838  (best val acc: 0.5892)
# Epoch [177/250]  Train Loss: 0.2953 | Acc: 0.8933  Val Loss: 2.4581 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [178/250]  Train Loss: 0.2756 | Acc: 0.8910  Val Loss: 2.2914 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [179/250]  Train Loss: 0.2727 | Acc: 0.9010  Val Loss: 2.2987 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [180/250]  Train Loss: 0.2718 | Acc: 0.8969  Val Loss: 2.3740 | Acc: 0.5351  (best val acc: 0.5892)
# Epoch [181/250]  Train Loss: 0.2685 | Acc: 0.8951  Val Loss: 2.4757 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [182/250]  Train Loss: 0.2743 | Acc: 0.8863  Val Loss: 2.5113 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [183/250]  Train Loss: 0.2541 | Acc: 0.8975  Val Loss: 2.5326 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [184/250]  Train Loss: 0.2781 | Acc: 0.8810  Val Loss: 2.4477 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [185/250]  Train Loss: 0.2444 | Acc: 0.8981  Val Loss: 2.4748 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [186/250]  Train Loss: 0.2544 | Acc: 0.9034  Val Loss: 2.7490 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [187/250]  Train Loss: 0.2754 | Acc: 0.8969  Val Loss: 2.4674 | Acc: 0.5189  (best val acc: 0.5892)
# Epoch [188/250]  Train Loss: 0.2401 | Acc: 0.9087  Val Loss: 2.5439 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [189/250]  Train Loss: 0.2581 | Acc: 0.8975  Val Loss: 2.5680 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [190/250]  Train Loss: 0.2369 | Acc: 0.9093  Val Loss: 2.7743 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [191/250]  Train Loss: 0.2334 | Acc: 0.9134  Val Loss: 2.6207 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [192/250]  Train Loss: 0.2518 | Acc: 0.8992  Val Loss: 2.6375 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [193/250]  Train Loss: 0.2639 | Acc: 0.8939  Val Loss: 2.8689 | Acc: 0.5784  (best val acc: 0.5892)
# Epoch [194/250]  Train Loss: 0.2385 | Acc: 0.9022  Val Loss: 2.6879 | Acc: 0.5514  (best val acc: 0.5892)
# Epoch [195/250]  Train Loss: 0.2522 | Acc: 0.9016  Val Loss: 2.7422 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [196/250]  Train Loss: 0.2397 | Acc: 0.9022  Val Loss: 2.8247 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [197/250]  Train Loss: 0.2450 | Acc: 0.9069  Val Loss: 2.9237 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [198/250]  Train Loss: 0.2544 | Acc: 0.9034  Val Loss: 2.6180 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [199/250]  Train Loss: 0.2451 | Acc: 0.9045  Val Loss: 2.4907 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [200/250]  Train Loss: 0.2382 | Acc: 0.9081  Val Loss: 2.5950 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [201/250]  Train Loss: 0.2536 | Acc: 0.8998  Val Loss: 2.7360 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [202/250]  Train Loss: 0.2427 | Acc: 0.9034  Val Loss: 2.5264 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [203/250]  Train Loss: 0.2356 | Acc: 0.9039  Val Loss: 2.7674 | Acc: 0.5297  (best val acc: 0.5892)
# Epoch [204/250]  Train Loss: 0.2369 | Acc: 0.8969  Val Loss: 2.6805 | Acc: 0.5459  (best val acc: 0.5892)
# Epoch [205/250]  Train Loss: 0.2420 | Acc: 0.9034  Val Loss: 2.9150 | Acc: 0.5676  (best val acc: 0.5892)
# Epoch [206/250]  Train Loss: 0.2370 | Acc: 0.9128  Val Loss: 2.5713 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [207/250]  Train Loss: 0.2306 | Acc: 0.9151  Val Loss: 2.7329 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [208/250]  Train Loss: 0.2523 | Acc: 0.9004  Val Loss: 2.4960 | Acc: 0.5405  (best val acc: 0.5892)
# Epoch [209/250]  Train Loss: 0.2485 | Acc: 0.9039  Val Loss: 2.7767 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [210/250]  Train Loss: 0.2546 | Acc: 0.8986  Val Loss: 2.7891 | Acc: 0.5730  (best val acc: 0.5892)
# Epoch [211/250]  Train Loss: 0.2383 | Acc: 0.8998  Val Loss: 2.7346 | Acc: 0.5568  (best val acc: 0.5892)
# Epoch [212/250]  Train Loss: 0.2141 | Acc: 0.9151  Val Loss: 2.8822 | Acc: 0.5892  (best val acc: 0.5892)
# Epoch [213/250]  Train Loss: 0.2250 | Acc: 0.8998  Val Loss: 2.5486 | Acc: 0.5622  (best val acc: 0.5892)
# Epoch [214/250]  Train Loss: 0.2195 | Acc: 0.9069  Val Loss: 2.6078 | Acc: 0.6000  (best val acc: 0.6000)
# Epoch [215/250]  Train Loss: 0.2264 | Acc: 0.9051  Val Loss: 2.6671 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [216/250]  Train Loss: 0.2580 | Acc: 0.8992  Val Loss: 3.0209 | Acc: 0.5459  (best val acc: 0.6000)
# Epoch [217/250]  Train Loss: 0.2576 | Acc: 0.9069  Val Loss: 2.7091 | Acc: 0.5297  (best val acc: 0.6000)
# Epoch [218/250]  Train Loss: 0.2395 | Acc: 0.9057  Val Loss: 2.7795 | Acc: 0.5568  (best val acc: 0.6000)
# Epoch [219/250]  Train Loss: 0.2368 | Acc: 0.9087  Val Loss: 2.8125 | Acc: 0.5459  (best val acc: 0.6000)
# Epoch [220/250]  Train Loss: 0.2301 | Acc: 0.9039  Val Loss: 2.8372 | Acc: 0.5622  (best val acc: 0.6000)
# Epoch [221/250]  Train Loss: 0.2273 | Acc: 0.9146  Val Loss: 2.7092 | Acc: 0.5405  (best val acc: 0.6000)
# Epoch [222/250]  Train Loss: 0.2342 | Acc: 0.9122  Val Loss: 3.0459 | Acc: 0.5189  (best val acc: 0.6000)
# Epoch [223/250]  Train Loss: 0.2222 | Acc: 0.9093  Val Loss: 2.9649 | Acc: 0.5514  (best val acc: 0.6000)
# Epoch [224/250]  Train Loss: 0.2228 | Acc: 0.9087  Val Loss: 2.8548 | Acc: 0.5459  (best val acc: 0.6000)
# Epoch [225/250]  Train Loss: 0.2116 | Acc: 0.9069  Val Loss: 2.9892 | Acc: 0.5730  (best val acc: 0.6000)
# Epoch [226/250]  Train Loss: 0.2213 | Acc: 0.9128  Val Loss: 2.9093 | Acc: 0.5351  (best val acc: 0.6000)
# Epoch [227/250]  Train Loss: 0.2017 | Acc: 0.9151  Val Loss: 2.9407 | Acc: 0.5459  (best val acc: 0.6000)
# Epoch [228/250]  Train Loss: 0.2074 | Acc: 0.9110  Val Loss: 3.0528 | Acc: 0.5622  (best val acc: 0.6000)
# Epoch [229/250]  Train Loss: 0.2095 | Acc: 0.9134  Val Loss: 2.9901 | Acc: 0.5622  (best val acc: 0.6000)
# Epoch [230/250]  Train Loss: 0.2187 | Acc: 0.9110  Val Loss: 2.9453 | Acc: 0.5730  (best val acc: 0.6000)
# Epoch [231/250]  Train Loss: 0.2219 | Acc: 0.9093  Val Loss: 2.8765 | Acc: 0.5892  (best val acc: 0.6000)
# Epoch [232/250]  Train Loss: 0.2175 | Acc: 0.9098  Val Loss: 2.8638 | Acc: 0.5459  (best val acc: 0.6000)
# Epoch [233/250]  Train Loss: 0.2152 | Acc: 0.9116  Val Loss: 2.6783 | Acc: 0.5297  (best val acc: 0.6000)
# Epoch [234/250]  Train Loss: 0.2055 | Acc: 0.9204  Val Loss: 2.7123 | Acc: 0.5405  (best val acc: 0.6000)
# Epoch [235/250]  Train Loss: 0.2267 | Acc: 0.9004  Val Loss: 2.9222 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [236/250]  Train Loss: 0.2241 | Acc: 0.9087  Val Loss: 2.9271 | Acc: 0.5459  (best val acc: 0.6000)
# Epoch [237/250]  Train Loss: 0.2148 | Acc: 0.9087  Val Loss: 3.0203 | Acc: 0.5243  (best val acc: 0.6000)
# Epoch [238/250]  Train Loss: 0.2190 | Acc: 0.9093  Val Loss: 2.8671 | Acc: 0.5514  (best val acc: 0.6000)
# Epoch [239/250]  Train Loss: 0.2080 | Acc: 0.9151  Val Loss: 2.9194 | Acc: 0.5351  (best val acc: 0.6000)
# Epoch [240/250]  Train Loss: 0.2068 | Acc: 0.9181  Val Loss: 2.9767 | Acc: 0.5622  (best val acc: 0.6000)
# Epoch [241/250]  Train Loss: 0.2050 | Acc: 0.9193  Val Loss: 2.6295 | Acc: 0.5297  (best val acc: 0.6000)
# Epoch [242/250]  Train Loss: 0.2086 | Acc: 0.9146  Val Loss: 2.8060 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [243/250]  Train Loss: 0.1897 | Acc: 0.9151  Val Loss: 2.8899 | Acc: 0.5297  (best val acc: 0.6000)
# Epoch [244/250]  Train Loss: 0.1902 | Acc: 0.9193  Val Loss: 3.1391 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [245/250]  Train Loss: 0.2036 | Acc: 0.9146  Val Loss: 2.9865 | Acc: 0.5514  (best val acc: 0.6000)
# Epoch [246/250]  Train Loss: 0.1932 | Acc: 0.9187  Val Loss: 2.7919 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [247/250]  Train Loss: 0.1864 | Acc: 0.9187  Val Loss: 3.0880 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [248/250]  Train Loss: 0.1924 | Acc: 0.9169  Val Loss: 3.0290 | Acc: 0.5622  (best val acc: 0.6000)
# Epoch [249/250]  Train Loss: 0.1912 | Acc: 0.9175  Val Loss: 2.6538 | Acc: 0.5676  (best val acc: 0.6000)
# Epoch [250/250]  Train Loss: 0.1980 | Acc: 0.9122  Val Loss: 3.0486 | Acc: 0.5784  (best val acc: 0.6000)

# %%
print(timeit)
# Out:
# 32.1970374584198

# %% [markdown]
# ## 6. Curves

# %%
import matplotlib.pyplot as plt

def plot_curve(values, title, ylabel):
    plt.figure(figsize=(6,4))
    plt.plot(values)
    plt.title(title)
    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.show()

plot_curve(history["train_loss"], "Train Loss", "Loss")
plot_curve(history["val_loss"], "Val Loss", "Loss")
plot_curve(history["train_acc"], "Train Accuracy", "Accuracy")
plot_curve(history["val_acc"], "Val Accuracy", "Accuracy")

# %% [markdown]
# ## 7. Evaluation

# %%
state_dict = torch.load("paper_style_cnn_best.pt")
model.load_state_dict(state_dict)
model.eval()
test_loss, test_acc, n_val = 0.0, 0.0, 0
with torch.inference_mode():
    for images, targets in test_loader:
        images, targets = images.to(device), targets.to(device)
        logits = model(images)
        loss = criterion(logits, targets)

        bsz = targets.size(0)
        test_loss += loss.item() * bsz
        test_acc  += (torch.argmax(logits, dim=1) == targets).float().mean().item() * bsz
        n_val    += bsz

test_loss /= max(n_val, 1)
test_acc  /= max(n_val, 1)

print(f"Test — Loss: {test_loss:.4f} | Acc: {test_acc:.4f}")
# Out:
# Test — Loss: 2.7284 | Acc: 0.6126

# %%
import torch
from collections import defaultdict

SUPERGROUPS = {
    "cancer":    [1, 4, 5],
    "precancer": [3],
    "benign":    [0, 2, 6, 7, 8],
}

super_names = list(SUPERGROUPS.keys())
super_to_id = {name: i for i, name in enumerate(super_names)}
fine_to_super = {}
for sname, idxs in SUPERGROUPS.items():
    for i in idxs:
        fine_to_super[i] = super_to_id[sname]

def super_probs_from_logits(logits: torch.Tensor) -> torch.Tensor:
    """
    Convert [B, 9] logits -> [B, 3] superclass probabilities
    by softmax over 9 classes then summing probs within each group.
    """
    probs = torch.softmax(logits, dim=1)  # [B, 9]
    super_cols = []
    for sname in super_names:
        group = SUPERGROUPS[sname]
        super_cols.append(probs[:, group].sum(dim=1))  # [B]
    return torch.stack(super_cols, dim=1)  # [B, 3]

@torch.no_grad()
def eval_superclasses(model, loader, device):
    model.eval()
    n, correct = 0, 0
    mean_super_prob = torch.zeros(len(super_names), dtype=torch.float64)

    cm = torch.zeros(len(super_names), len(super_names), dtype=torch.int64)

    for images, targets in loader:
        images = images.to(device)
        targets = targets.to(device)

        logits = model(images)
        s_probs = super_probs_from_logits(logits)

        # map fine labels -> super labels
        super_targets = torch.tensor([fine_to_super[int(t)] for t in targets], device=device)

        # predictions at the superclass level
        super_preds = s_probs.argmax(dim=1)

        # accuracy
        correct += (super_preds == super_targets).sum().item()
        n += targets.size(0)

        # accumulate mean probs
        mean_super_prob += s_probs.sum(dim=0).cpu().double()

        # confusion matrix
        for t, p in zip(super_targets.cpu(), super_preds.cpu()):
            cm[t, p] += 1

    acc = correct / max(n, 1)

    # Normalize mean probs
    mean_super_prob = (mean_super_prob / max(n, 1)).tolist()

    print("Superclass Names:", super_names)
    print(f"Superclass Accuracy: {acc:.4f}")
    print("Mean predicted probability per superclass:")
    for name, mp in zip(super_names, mean_super_prob):
        print(f"  - {name:9s}: {mp:.4f}")

    print("\nSuperclass Confusion Matrix (rows=true, cols=pred):")
    header = "          " + " ".join([f"{n[:8]:>9}" for n in super_names])
    print(header)
    for i, row in enumerate(cm.tolist()):
        print(f"{super_names[i][:8]:>9} " + " ".join([f"{v:9d}" for v in row]))

    return {"accuracy": acc, "mean_super_prob": mean_super_prob, "confusion": cm}

super_eval = eval_superclasses(model, val_loader, device)
# Out:
# Superclass Names: ['cancer', 'precancer', 'benign']
# Superclass Accuracy: 0.6919
# Mean predicted probability per superclass:
#   - cancer   : 0.5921
#   - precancer: 0.2029
#   - benign   : 0.2050
#
# Superclass Confusion Matrix (rows=true, cols=pred):
#              cancer  precance    benign
#    cancer        86         7        16
#  precance         7        25         1
#    benign        17         9        17
